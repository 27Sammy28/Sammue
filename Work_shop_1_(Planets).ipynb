# %% [markdown]
# <a href="https://colab.research.google.com/github/27Sammy28/Sammue/blob/main/Work_shop_1_(Planets).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
from astropy.table import Table
import pandas as pd
import matplotlib.pyplot as plt
import os
from  google.colab import files

# %% [markdown]
# # New Section

# %%
x= files.upload()
# Out:
#      <input type="file" id="files-5e8a6f2f-3f16-482c-a8d6-8bfedff1ba23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e8a6f2f-3f16-482c-a8d6-8bfedff1ba23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
my_data= pd.read_csv("exoplanet.eu_catalog.csv")
my_data
# Out:
#          # name planet_status   mass  mass_error_min  mass_error_max  \
# 0      11 Com b     Confirmed    NaN             NaN             NaN
# 1      11 Oph b     Confirmed  21.00            3.00            3.00
# 2      11 UMi b     Confirmed    NaN             NaN             NaN
# 3      14 And b     Confirmed    NaN             NaN             NaN
# 4      14 Her b     Confirmed    NaN             NaN             NaN
# ...         ...           ...    ...             ...             ...
# 5501  ups And c     Confirmed   9.10            2.93            5.04
# 5502  ups And d     Confirmed  23.58            2.29            2.93
# 5503  ups And e     Confirmed    NaN             NaN             NaN
# 5504  ups Leo b     Confirmed    NaN             NaN             NaN
# 5505  zet Del B     Confirmed  40.00            5.00           15.00
#
#       mass_sini  mass_sini_error_min  mass_sini_error_max  radius  \
# 0       16.1284              1.53491              1.53491     NaN
# ...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5506 entries, 0 to 5505
# Data columns (total 98 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   # name                      5506 non-null   object
#  1   planet_status               5506 non-null   object
#  2   mass                        1994 non-null   float64
#  3   mass_error_min              1860 non-null   float64
#  4   mass_error_max              1848 non-null   float64
#  5   mass_sini                   1172 non-null   float64
#  6   mass_sini_error_min         1019 non-null   float64
#  7   mass_sini_error_max         1018 non-null   float64
#  8   radius                      3956 non-null   float64
#  9   radius_error_min            3793 non-null   float64
#  10  radius_error_max            3793 non-null   float64
#  11  orbital_period              5014 non-null   float64
#  12  orbital_period_error_min    4757 non-null   float64
# ...

# %%
my_data.shape
# Out:
# (5506, 98)

# %%
my_data= pd.read_csv("exoplanet.eu_catalog.csv", index_col=1)
my_data
# Out:
#                   # name   mass  mass_error_min  mass_error_max  mass_sini  \
# planet_status
# Confirmed       11 Com b    NaN             NaN             NaN    16.1284
# Confirmed       11 Oph b  21.00            3.00            3.00        NaN
# Confirmed       11 UMi b    NaN             NaN             NaN    11.0873
# Confirmed       14 And b    NaN             NaN             NaN     4.6840
# Confirmed       14 Her b    NaN             NaN             NaN        NaN
# ...                  ...    ...             ...             ...        ...
# Confirmed      ups And c   9.10            2.93            5.04     1.8000
# Confirmed      ups And d  23.58            2.29            2.93    10.1900
# Confirmed      ups And e    NaN             NaN             NaN     1.0590
# Confirmed      ups Leo b    NaN             NaN             NaN     0.5100
# Confirmed      zet Del B  40.00            5.00           15.00        NaN
#
# ...

# %%
y=files.upload()
# Out:
#      <input type="file" id="files-7eba4dd6-0bee-4682-9af3-82a6937297e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7eba4dd6-0bee-4682-9af3-82a6937297e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
your_data=pd.read_csv("planetary_systems.csv")
your_data
# Out:
#          pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0       11 Com b   11 Com             1        2        1  Radial Velocity
# 1       11 Com b   11 Com             0        2        1  Radial Velocity
# 2       11 UMi b   11 UMi             0        1        1  Radial Velocity
# 3       11 UMi b   11 UMi             0        1        1  Radial Velocity
# 4       11 UMi b   11 UMi             1        1        1  Radial Velocity
# ...          ...      ...           ...      ...      ...              ...
# 33967  ups And d  ups And             0        2        3  Radial Velocity
# 33968  ups And d  ups And             0        2        3  Radial Velocity
# 33969  ups Leo b  ups Leo             1        1        1  Radial Velocity
# 33970   xi Aql b   xi Aql             0        1        1  Radial Velocity
# 33971   xi Aql b   xi Aql             1        1        1  Radial Velocity
#
# ...

# %%
my_data.head()
# Out:
#      # name planet_status  mass  mass_error_min  mass_error_max  mass_sini  \
# 0  11 Com b     Confirmed   NaN             NaN             NaN    16.1284
# 1  11 Oph b     Confirmed  21.0             3.0             3.0        NaN
# 2  11 UMi b     Confirmed   NaN             NaN             NaN    11.0873
# 3  14 And b     Confirmed   NaN             NaN             NaN     4.6840
# 4  14 Her b     Confirmed   NaN             NaN             NaN        NaN
#
#    mass_sini_error_min  mass_sini_error_max  radius  radius_error_min  ...  \
# 0              1.53491              1.53491     NaN               NaN  ...
# 1                  NaN                  NaN     NaN               NaN  ...
# 2              1.10000              1.10000     NaN               NaN  ...
# 3              0.23000              0.23000     NaN               NaN  ...
# 4              4.95000              4.95000     NaN               NaN  ...
#
# ...

# %%
your_data.head()
# Out:
#     pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0  11 Com b   11 Com             1        2        1  Radial Velocity
# 1  11 Com b   11 Com             0        2        1  Radial Velocity
# 2  11 UMi b   11 UMi             0        1        1  Radial Velocity
# 3  11 UMi b   11 UMi             0        1        1  Radial Velocity
# 4  11 UMi b   11 UMi             1        1        1  Radial Velocity
#
#    disc_year                           disc_facility              soltype  \
# 0       2007                        Xinglong Station  Published Confirmed
# 1       2007                        Xinglong Station  Published Confirmed
# 2       2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 3       2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4       2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
#
#    pl_controv_flag  ... sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  \
# ...

# %%
pip install dabl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.3/564.3 kB 9.0 MB/s eta 0:00:00
# ...

# %%
import dabl
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')
dabl.plot(your_data, target_col = 'st_mass')
# Out:
# Target looks like regression
# [<Axes: title={'center': 'Target distribution'}, xlabel='st_mass', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=8.82E-01'}, xlabel='st_rad', ylabel='st_mass'>,
#          <Axes: title={'center': 'F=8.54E-01'}, xlabel='st_teff'>,
#          <Axes: title={'center': 'F=-4.97E-01'}, xlabel='st_masserr2'>,
#          <Axes: title={'center': 'F=4.70E-01'}, xlabel='pl_insolerr1'>,
#          <Axes: title={'center': 'F=4.69E-01'}, xlabel='pl_radjerr1'>],
#         [<Axes: title={'center': 'F=-4.55E-01'}, xlabel='pl_insolerr2', ylabel='st_mass'>,
#          <Axes: title={'center': 'F=-4.47E-01'}, xlabel='st_raderr2'>,
#          <Axes: title={'center': 'F=4.21E-01'}, xlabel='pl_radj'>,
#          <Axes: title={'center': 'F=4.18E-01'}, xlabel='pl_bmasse'>,
#          <Axes: title={'center': 'F=4.09E-01'}, xlabel='st_masserr1'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=2.12E-01'}, xlabel='st_mass', ylabel='default_flag'>,
# ...

# %%
your_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33972 entries, 0 to 33971
# Data columns (total 92 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          33972 non-null  object
#  1   hostname         33972 non-null  object
#  2   default_flag     33972 non-null  int64
#  3   sy_snum          33972 non-null  int64
#  4   sy_pnum          33972 non-null  int64
#  5   discoverymethod  33972 non-null  object
#  6   disc_year        33972 non-null  int64
#  7   disc_facility    33972 non-null  object
#  8   soltype          33972 non-null  object
#  9   pl_controv_flag  33972 non-null  int64
#  10  pl_refname       33972 non-null  object
#  11  pl_orbper        30993 non-null  float64
#  12  pl_orbpererr1    29736 non-null  float64
#  13  pl_orbpererr2    29735 non-null  float64
#  14  pl_orbperlim     30993 non-null  float64
#  15  pl_orbsmax       18640 non-null  float64
# ...

# %%
corr_matrix= my_data.corr()
plt.figure(figsize=(10, 6), dpi=120)
sns.heatmap(corr_matrix, annot=True, fmt='1f', square=True, cbar=True)
# Out:
# <Axes: >

# %%
dabl.plot(your_data, target_col = 'st_rad')
# Out:
# Target looks like regression
# [<Axes: title={'center': 'Target distribution'}, xlabel='st_rad', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=-9.66E-01'}, xlabel='st_logg', ylabel='st_rad'>,
#          <Axes: title={'center': 'F=8.81E-01'}, xlabel='st_mass'>,
#          <Axes: title={'center': 'F=7.86E-01'}, xlabel='st_teff'>,
#          <Axes: title={'center': 'F=-5.15E-01'}, xlabel='st_raderr2'>,
#          <Axes: title={'center': 'F=4.71E-01'}, xlabel='pl_insol'>],
#         [<Axes: title={'center': 'F=-4.67E-01'}, xlabel='pl_bmassjerr2', ylabel='st_rad'>,
#          <Axes: title={'center': 'F=4.62E-01'}, xlabel='st_masserr1'>,
#          <Axes: title={'center': 'F=-4.54E-01'}, xlabel='st_masserr2'>,
#          <Axes: title={'center': 'F=4.47E-01'}, xlabel='pl_bmasse'>,
#          <Axes: title={'center': 'F=-4.46E-01'}, xlabel='pl_insolerr2'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=1.72E-01'}, xlabel='st_rad', ylabel='default_flag'>,
# ...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5506 entries, Confirmed to Confirmed
# Data columns (total 97 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   # name                      5506 non-null   object
#  1   mass                        1994 non-null   float64
#  2   mass_error_min              1860 non-null   float64
#  3   mass_error_max              1848 non-null   float64
#  4   mass_sini                   1172 non-null   float64
#  5   mass_sini_error_min         1019 non-null   float64
#  6   mass_sini_error_max         1018 non-null   float64
#  7   radius                      3956 non-null   float64
#  8   radius_error_min            3793 non-null   float64
#  9   radius_error_max            3793 non-null   float64
#  10  orbital_period              5014 non-null   float64
#  11  orbital_period_error_min    4757 non-null   float64
# ...

# %%
z=files.upload()
# Out:
#      <input type="file" id="files-eff66bb9-dbd3-4450-86e0-a13a0360e88f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eff66bb9-dbd3-4450-86e0-a13a0360e88f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
our_data=pd.read_csv('phl_exoplanet_catalog_2019.csv')
our_data
# Out:
#           P_NAME  P_STATUS      P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# 0       11 Com b       3.0  6165.86330        -476.74200         476.74200
# 1       11 UMi b       3.0  4684.78480        -794.57001         794.57001
# 2       14 And b       3.0  1525.57440               NaN               NaN
# 3       14 Her b       3.0  1481.07850         -47.67420          47.67420
# 4     16 Cyg B b       3.0   565.73385         -25.42624          25.42624
# ...          ...       ...         ...               ...               ...
# 4043    K2-296 b       3.0         NaN               NaN               NaN
# 4044    K2-296 c       3.0         NaN               NaN               NaN
# 4045   GJ 1061 b       3.0     1.38000           0.15000           0.16000
# 4046   GJ 1061 c       3.0     1.75000           0.23000           0.23000
# 4047   GJ 1061 d       3.0     1.68000           0.24000           0.25000
#
# ...

# %%
our_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4048 entries, 0 to 4047
# Columns: 112 entries, P_NAME to P_SEMI_MAJOR_AXIS_EST
# dtypes: float64(94), int64(4), object(14)
# memory usage: 3.5+ MB

# %%
import dabl
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')
dabl.plot(our_data, target_col = 'P_HABITABLE')
# Out:
# Target looks like classification
# Showing only top 10 of 84 continuous features
# Linear Discriminant Analysis training set score: 0.865
# [<Axes: title={'center': 'Target distribution'}, xlabel='count', ylabel='P_HABITABLE'>,
#  [<Figure size 2000x600 with 10 Axes>,
#   array([[<Axes: title={'center': '0.786'}, xlabel='P_ESI', ylabel='P_OMEGA_ERROR_MAX'>,
#           <Axes: title={'center': '0.781'}, xlabel='P_ESI', ylabel='P_TEMP_EQUIL'>,
#           <Axes: title={'center': '0.773'}, xlabel='P_ESI', ylabel='P_TEMP_EQUIL_MIN'>,
#           <Axes: title={'center': '0.768'}, xlabel='P_ESI', ylabel='P_TEMP_EQUIL_MAX'>]],
#         dtype=object),
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 400x400 with 1 Axes>],
#  array([[<Axes: title={'center': 'P_TYPE_TEMP'}>,
#          <Axes: title={'center': 'P_TYPE'}>,
#          <Axes: title={'center': 'S_TYPE_TEMP'}>,
#          <Axes: title={'center': 'P_DETECTION'}>]], dtype=object)]

# %%
dabl.plot(our_data, target_col = 'P_MASS')
# Out:
# Target looks like regression
# [<Axes: title={'center': 'Target distribution'}, xlabel='P_MASS', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=1.00E+00'}, xlabel='P_MASS_EST', ylabel='P_MASS'>,
#          <Axes: title={'center': 'F=-8.94E-01'}, xlabel='P_MASS_ERROR_MIN'>,
#          <Axes: title={'center': 'F=6.62E-01'}, xlabel='P_HILL_SPHERE'>,
#          <Axes: title={'center': 'F=6.60E-01'}, xlabel='P_RADIUS'>,
#          <Axes: title={'center': 'F=-6.43E-01'}, xlabel='P_RADIUS_ERROR_MIN'>],
#         [<Axes: title={'center': 'F=6.00E-01'}, xlabel='P_RADIUS_ERROR_MAX', ylabel='P_MASS'>,
#          <Axes: title={'center': 'F=5.58E-01'}, xlabel='P_GRAVITY'>,
#          <Axes: title={'center': 'F=4.83E-01'}, xlabel='S_LUMINOSITY'>,
#          <Axes: title={'center': 'F=4.48E-01'}, xlabel='P_SEMI_MAJOR_AXIS'>,
#          <Axes: title={'center': 'F=-4.26E-01'}, xlabel='P_SEMI_MAJOR_AXIS_ERROR_MIN'>]],
#        dtype=object),
# ...

# %%
corr_matrix= our_data.corr()
plt.figure(figsize=(10, 6), dpi=120)
sns.heatmap(corr_matrix, annot=True, fmt='1f', square=True, cbar=True)
# Out:
# <Axes: >

# %%
import category_encoders as ce
from sklearn.model_selection import train_test_split

X = our_data.drop(columns=['P_HABITABLE'], axis=1)
y = our_data['P_HABITABLE']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
pip install category_encoders
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 2.5 MB/s eta 0:00:00
# ...

# %%
X_train[X_train.select_dtypes(include=['object']).columns]
# Out:
#              P_NAME   P_UPDATED      P_DETECTION       S_NAME          S_TYPE  \
# 1052       K2-190 c  2018-02-15          Transit       K2-190             NaN
# 4017    gam 1 Leo b  2019-01-31  Radial Velocity    gam 1 Leo  K1 IIIb Fe-0.5
# 3321   Kepler-737 b  2016-05-10          Transit   Kepler-737             NaN
# 3543   Kepler-904 b  2016-05-10          Transit   Kepler-904             NaN
# 1631  Kepler-1212 b  2016-05-10          Transit  Kepler-1212             NaN
# ...             ...         ...              ...          ...             ...
# 1597  Kepler-1185 b  2016-05-10          Transit  Kepler-1185             NaN
# 2144  Kepler-1604 b  2016-05-10          Transit  Kepler-1604             NaN
# 939        K2-113 b  2018-10-26          Transit       K2-113               G
# 4015      eps Eri b  2015-09-03  Radial Velocity      eps Eri            K2 V
# 2109  Kepler-1576 b  2016-05-10          Transit  Kepler-1576             NaN
#
# ...

# %%
X_train['P_DETECTION'].value_counts()
# Out:
# Transit                          2331
# Radial Velocity                   572
# Microlensing                       59
# Imaging                            39
# Transit Timing Variations          14
# Eclipse Timing Variations           9
# Pulsar Timing                       5
# Orbital Brightness Modulation       4
# Pulsation Timing Variations         2
# Astrometry                          1
# Name: P_DETECTION, dtype: int64
